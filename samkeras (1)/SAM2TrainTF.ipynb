# %%
# Print current working directory
import os
print("Current working directory:", os.getcwd())

# Create a virtual environment (if it doesn't exist)
print("Creating virtual environment...")
# !python3 -m venv .venv

# Activate virtual environment
print("Activating virtual environment...")
# !source .venv/bin/activate

# Install required system dependencies
print("Installing system dependencies...")
# !sudo yum install -y cairo-devel pkgconfig

# Install required Python package
print("Installing Python package pygobject...")
# !pip install pygobject

# Upgrade pip
print("Upgrading pip...")
# !pip install --upgrade pip

# Install your package
print("Installing package...")
# !pip install -e . --verbose  # Assuming you're in the Sam2Keras directory
# Out:
# Current working directory: /workspaces/segment-anything-2/samkeras (1)
# Creating virtual environment...
# Activating virtual environment...
# Installing system dependencies...
# sudo: yum: command not found
# Installing Python package pygobject...
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/tqdm-4.66.5-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/hydra_core-1.4.0.dev1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/omegaconf-2.4.0.dev3-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/torchvision-0.19.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/iopath-0.1.10-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/SAM_2-1.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/portalocker-2.10.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting pygobject
#   Using cached pygobject-3.48.2.tar.gz (715 kB)
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [57 lines of output]
#       DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/tqdm-4.66.5-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#       DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/hydra_core-1.4.0.dev1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#       DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/omegaconf-2.4.0.dev3-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#       DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/torchvision-0.19.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#       DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/iopath-0.1.10-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#       DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/SAM_2-1.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#       DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/portalocker-2.10.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#       Collecting meson-python>=0.12.1
#         Using cached meson_python-0.16.0-py3-none-any.whl.metadata (4.1 kB)
#       Collecting pycairo>=1.16
#         Using cached pycairo-1.26.1.tar.gz (346 kB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'done'
#       Collecting meson>=1.2.3 (from meson-python>=0.12.1)
#         Using cached meson-1.5.1-py3-none-any.whl.metadata (1.8 kB)
#       Collecting packaging>=19.0 (from meson-python>=0.12.1)
#         Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
#       Collecting pyproject-metadata>=0.7.1 (from meson-python>=0.12.1)
#         Using cached pyproject_metadata-0.8.0-py3-none-any.whl.metadata (3.0 kB)
#       Using cached meson_python-0.16.0-py3-none-any.whl (26 kB)
#       Using cached meson-1.5.1-py3-none-any.whl (966 kB)
#       Using cached packaging-24.1-py3-none-any.whl (53 kB)
#       Using cached pyproject_metadata-0.8.0-py3-none-any.whl (7.5 kB)
#       Building wheels for collected packages: pycairo
#         Building wheel for pycairo (pyproject.toml): started
#         Building wheel for pycairo (pyproject.toml): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Building wheel for pycairo (pyproject.toml) did not run successfully.
#         │ exit code: 1
#         ╰─> [15 lines of output]
#             running bdist_wheel
#             running build
#             running build_py
#             creating build
#             creating build/lib.linux-x86_64-cpython-312
#             creating build/lib.linux-x86_64-cpython-312/cairo
#             copying cairo/__init__.py -> build/lib.linux-x86_64-cpython-312/cairo
#             copying cairo/__init__.pyi -> build/lib.linux-x86_64-cpython-312/cairo
#             copying cairo/py.typed -> build/lib.linux-x86_64-cpython-312/cairo
#             running build_ext
#             Package cairo was not found in the pkg-config search path.
#             Perhaps you should add the directory containing `cairo.pc'
#             to the PKG_CONFIG_PATH environment variable
#             No package 'cairo' found
#             Command '['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']' returned non-zero exit status 1.
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for pycairo
#       Failed to build pycairo
#       ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pycairo)
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Upgrading pip...
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/tqdm-4.66.5-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/hydra_core-1.4.0.dev1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/omegaconf-2.4.0.dev3-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/torchvision-0.19.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/iopath-0.1.10-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/SAM_2-1.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/portalocker-2.10.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: pip in /usr/local/python/3.12.1/lib/python3.12/site-packages (24.2)
# Installing package...
# Using pip 24.2 from /usr/local/python/3.12.1/lib/python3.12/site-packages/pip (python 3.12)
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/tqdm-4.66.5-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/hydra_core-1.4.0.dev1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/omegaconf-2.4.0.dev3-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/torchvision-0.19.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/iopath-0.1.10-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/SAM_2-1.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/portalocker-2.10.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Obtaining file:///workspaces/segment-anything-2/samkeras%20%281%29
#   Preparing metadata (setup.py) ...   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-eh42026z/sam2keras.egg-info
#   writing /tmp/pip-pip-egg-info-eh42026z/sam2keras.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-eh42026z/sam2keras.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-eh42026z/sam2keras.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-eh42026z/sam2keras.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-eh42026z/sam2keras.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-eh42026z/sam2keras.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-eh42026z/sam2keras.egg-info/SOURCES.txt'
# done
# Requirement already satisfied: tensorflow>=2.12 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sam2keras==0.1.0) (2.17.0)
# Requirement already satisfied: opencv-python in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sam2keras==0.1.0) (4.10.0.84)
# Requirement already satisfied: numpy in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sam2keras==0.1.0) (1.26.4)
# Collecting pygobject (from sam2keras==0.1.0)
#   Using cached pygobject-3.48.2.tar.gz (715 kB)
#   Installing build dependencies ...   Running command pip subprocess to install build dependencies
#   Using pip 24.2 from /usr/local/python/3.12.1/lib/python3.12/site-packages/pip (python 3.12)
#   DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/tqdm-4.66.5-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#   DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/hydra_core-1.4.0.dev1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#   DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/omegaconf-2.4.0.dev3-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#   DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/torchvision-0.19.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#   DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/iopath-0.1.10-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#   DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/SAM_2-1.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#   DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/portalocker-2.10.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#   Collecting meson-python>=0.12.1
#     Obtaining dependency information for meson-python>=0.12.1 from https://files.pythonhosted.org/packages/91/c0/104cb6244c83fe6bc3886f144cc433db0c0c78efac5dc00e409a5a08c87d/meson_python-0.16.0-py3-none-any.whl.metadata
#     Using cached meson_python-0.16.0-py3-none-any.whl.metadata (4.1 kB)
#   Collecting pycairo>=1.16
#     Using cached pycairo-1.26.1.tar.gz (346 kB)
#     Installing build dependencies: started
#     Running command pip subprocess to install build dependencies
#     Using pip 24.2 from /usr/local/python/3.12.1/lib/python3.12/site-packages/pip (python 3.12)
#     DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/tqdm-4.66.5-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#     DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/hydra_core-1.4.0.dev1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#     DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/omegaconf-2.4.0.dev3-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#     DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/torchvision-0.19.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#     DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/iopath-0.1.10-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#     DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/SAM_2-1.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#     DEPRECATION: Loading egg at /home/codespace/.local/lib/python3.12/site-packages/portalocker-2.10.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#     Collecting setuptools
#       Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/07/6a/0270e295bf30c37567736b7fca10167640898214ff911273af37ddb95770/setuptools-73.0.1-py3-none-any.whl.metadata
#       Using cached setuptools-73.0.1-py3-none-any.whl.metadata (6.6 kB)
#     Using cached setuptools-73.0.1-py3-none-any.whl (2.3 MB)
#     Installing collected packages: setuptools
#     Successfully installed setuptools-73.0.1
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Running command Getting requirements to build wheel
#     running egg_info
#     writing pycairo.egg-info/PKG-INFO
#     writing dependency_links to pycairo.egg-info/dependency_links.txt
#     writing top-level names to pycairo.egg-info/top_level.txt
#     reading manifest file 'pycairo.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     no previously-included directories found matching 'docs/_build'
#     warning: no files found matching 'README' under directory 'tests'
#     warning: no files found matching 'README' under directory 'examples'
#     adding license file 'COPYING'
#     adding license file 'COPYING-LGPL-2.1'
#     adding license file 'COPYING-MPL-1.1'
#     writing manifest file 'pycairo.egg-info/SOURCES.txt'
#     Getting requirements to build wheel: finished with status 'done'
#     Preparing metadata (pyproject.toml): started
#     Running command Preparing metadata (pyproject.toml)
#     running dist_info
#     creating /tmp/pip-modern-metadata-5vn1ifxk/pycairo.egg-info
#     writing /tmp/pip-modern-metadata-5vn1ifxk/pycairo.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-modern-metadata-5vn1ifxk/pycairo.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-modern-metadata-5vn1ifxk/pycairo.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-modern-metadata-5vn1ifxk/pycairo.egg-info/SOURCES.txt'
#     reading manifest file '/tmp/pip-modern-metadata-5vn1ifxk/pycairo.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     no previously-included directories found matching 'docs/_build'
#     warning: no files found matching 'README' under directory 'tests'
#     warning: no files found matching 'README' under directory 'examples'
#     adding license file 'COPYING'
#     adding license file 'COPYING-LGPL-2.1'
#     adding license file 'COPYING-MPL-1.1'
#     writing manifest file '/tmp/pip-modern-metadata-5vn1ifxk/pycairo.egg-info/SOURCES.txt'
#     creating '/tmp/pip-modern-metadata-5vn1ifxk/pycairo-1.26.1.dist-info'
#     Preparing metadata (pyproject.toml): finished with status 'done'
#   Collecting meson>=1.2.3 (from meson-python>=0.12.1)
#     Obtaining dependency information for meson>=1.2.3 from https://files.pythonhosted.org/packages/b7/33/513a9ca4fd5892463abb38592105b78fd425214f7983033633e2e48cbd30/meson-1.5.1-py3-none-any.whl.metadata
#     Using cached meson-1.5.1-py3-none-any.whl.metadata (1.8 kB)
#   Collecting packaging>=19.0 (from meson-python>=0.12.1)
#     Obtaining dependency information for packaging>=19.0 from https://files.pythonhosted.org/packages/08/aa/cc0199a5f0ad350994d660967a8efb233fe0416e4639146c089643407ce6/packaging-24.1-py3-none-any.whl.metadata
#     Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
#   Collecting pyproject-metadata>=0.7.1 (from meson-python>=0.12.1)
#     Obtaining dependency information for pyproject-metadata>=0.7.1 from https://files.pythonhosted.org/packages/aa/5f/bb5970d3d04173b46c9037109f7f05fc8904ff5be073ee49bb6ff00301bc/pyproject_metadata-0.8.0-py3-none-any.whl.metadata
#     Using cached pyproject_metadata-0.8.0-py3-none-any.whl.metadata (3.0 kB)
#   Using cached meson_python-0.16.0-py3-none-any.whl (26 kB)
#   Using cached meson-1.5.1-py3-none-any.whl (966 kB)
#   Using cached packaging-24.1-py3-none-any.whl (53 kB)
#   Using cached pyproject_metadata-0.8.0-py3-none-any.whl (7.5 kB)
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (pyproject.toml): started
#     Running command Building wheel for pycairo (pyproject.toml)
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-cpython-312
#     creating build/lib.linux-x86_64-cpython-312/cairo
#     copying cairo/__init__.py -> build/lib.linux-x86_64-cpython-312/cairo
#     copying cairo/__init__.pyi -> build/lib.linux-x86_64-cpython-312/cairo
#     copying cairo/py.typed -> build/lib.linux-x86_64-cpython-312/cairo
#     running build_ext
#     Package cairo was not found in the pkg-config search path.
#     Perhaps you should add the directory containing `cairo.pc'
#     to the PKG_CONFIG_PATH environment variable
#     No package 'cairo' found
#     Command '['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']' returned non-zero exit status 1.
#     error: subprocess-exited-with-error
#
#     × Building wheel for pycairo (pyproject.toml) did not run successfully.
#     │ exit code: 1
#     ╰─> See above for output.
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#     full command: /usr/local/python/3.12.1/bin/python3 /usr/local/python/3.12.1/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py build_wheel /tmp/tmp84ubjzpz
#     cwd: /tmp/pip-install-h902ox_z/pycairo_ec5af753f7054f0caa8b1a6e7c2d179f
#     Building wheel for pycairo (pyproject.toml): finished with status 'error'
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pycairo)
#
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   full command: /usr/local/python/3.12.1/bin/python3 /usr/local/python/3.12.1/lib/python3.12/site-packages/pip/__pip-runner__.py install --ignore-installed --no-user --prefix /tmp/pip-build-env-xtiay3hv/overlay --no-warn-script-location --disable-pip-version-check -v --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- 'meson-python>=0.12.1' 'pycairo>=1.16'
#   cwd: [inherit]
# error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# In your Jupyter Notebook cell:
# %run train.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /workspaces/segment-anything-2/samkeras (1)/train.py:15
#      13 from sam2.modeling.sam2_utils import LayerNorm2d, DropPath, MLP, get_1d_sine_pe, select_closest_cond_frames
#      14 import os
# ---> 15 import cv2
#      16 import tarfile
#      17 import numpy as np
#
# ImportError: libGL.so.1: cannot open shared object file: No such file or directory

# %%
# !ls
# Out:
# Backbones			    sam2_base.py
# Modeling			    sam2_image_predictor.py
# SAM2TrainTF.ipynb		    sam2_video_predictor.py
# Sam				    sam2keras.egg-info
# __init__.py			    samkeras.zip
# automatic_mask_generator.py	    setup.py
# build_sam.py			    train.py
# new-workspace.jupyterlab-workspace  zip.ipynb
# position_encoder.py
