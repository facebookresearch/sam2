# %%
# Print current working directory
import os
print("Current working directory:", os.getcwd())

# Create a virtual environment (if it doesn't exist)
print("Creating virtual environment...")
# !python3 -m venv .venv

# Activate virtual environment
print("Activating virtual environment...")
# !source .venv/bin/activate

# Install required system dependencies
print("Installing system dependencies...")
# !sudo yum install -y cairo-devel pkgconfig

# Install required Python package
print("Installing Python package pygobject...")
# !pip install pygobject

# Upgrade pip
print("Upgrading pip...")
# !pip install --upgrade pip

# Install your package
print("Installing package...")
# !pip install -e . --verbose  # Assuming you're in the Sam2Keras directory
# Out:
# Current working directory: /home/ec2-user/SageMaker/Sam2Keras
# Creating virtual environment...
# Activating virtual environment...
# Installing system dependencies...
# Loaded plugins: dkms-build-requires, extras_suggestions, kernel-livepatch,
#               : langpacks, priorities, update-motd, versionlock
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# nvidia-container-toolkit                                                  75/75
# 63 packages excluded due to repository priority protections
# Package 1:pkgconfig-0.27.1-4.amzn2.0.2.x86_64 already installed and latest version
# Resolving Dependencies
# --> Running transaction check
# ---> Package cairo-devel.x86_64 0:1.15.12-4.amzn2 will be installed
# --> Processing Dependency: pkgconfig(fontconfig) >= 2.2.95 for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(freetype2) >= 9.7.3 for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(glib-2.0) >= 2.14 for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(pixman-1) >= 0.30.0 for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(xcb) >= 1.6 for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(xcb-render) >= 1.6 for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(xrender) >= 0.6 for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(egl) for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(gl) for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(gobject-2.0) for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(libpng) for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(x11) for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(xcb-shm) for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Processing Dependency: pkgconfig(xext) for package: cairo-devel-1.15.12-4.amzn2.x86_64
# --> Running transaction check
# ---> Package fontconfig-devel.x86_64 0:2.13.0-4.3.amzn2 will be installed
# --> Processing Dependency: pkgconfig(expat) for package: fontconfig-devel-2.13.0-4.3.amzn2.x86_64
# --> Processing Dependency: pkgconfig(uuid) for package: fontconfig-devel-2.13.0-4.3.amzn2.x86_64
# ---> Package freetype-devel.x86_64 0:2.8-14.amzn2.1.2 will be installed
# ---> Package glib2-devel.x86_64 0:2.56.1-9.amzn2.0.8 will be installed
# ---> Package libX11-devel.x86_64 0:1.6.7-3.amzn2.0.5 will be installed
# --> Processing Dependency: pkgconfig(kbproto) for package: libX11-devel-1.6.7-3.amzn2.0.5.x86_64
# --> Processing Dependency: pkgconfig(xproto) for package: libX11-devel-1.6.7-3.amzn2.0.5.x86_64
# ---> Package libXext-devel.x86_64 0:1.3.3-3.amzn2.0.2 will be installed
# ---> Package libXrender-devel.x86_64 0:0.9.10-1.amzn2.0.2 will be installed
# ---> Package libpng-devel.x86_64 2:1.5.13-8.amzn2.0.5 will be installed
# ---> Package libxcb-devel.x86_64 0:1.12-1.amzn2.0.2 will be installed
# --> Processing Dependency: pkgconfig(xau) >= 0.99.2 for package: libxcb-devel-1.12-1.amzn2.0.2.x86_64
# ---> Package mesa-libEGL-devel.x86_64 0:18.3.4-5.amzn2.0.1 will be installed
# --> Processing Dependency: mesa-khr-devel(x86-64) = 18.3.4-5.amzn2.0.1 for package: mesa-libEGL-devel-18.3.4-5.amzn2.0.1.x86_64
# --> Processing Dependency: pkgconfig(libdrm) >= 2.4.75 for package: mesa-libEGL-devel-18.3.4-5.amzn2.0.1.x86_64
# --> Processing Dependency: pkgconfig(xdamage) >= 1.1 for package: mesa-libEGL-devel-18.3.4-5.amzn2.0.1.x86_64
# --> Processing Dependency: pkgconfig(xfixes) for package: mesa-libEGL-devel-18.3.4-5.amzn2.0.1.x86_64
# --> Processing Dependency: pkgconfig(xxf86vm) for package: mesa-libEGL-devel-18.3.4-5.amzn2.0.1.x86_64
# ---> Package mesa-libGL-devel.x86_64 0:18.3.4-5.amzn2.0.1 will be installed
# --> Processing Dependency: gl-manpages for package: mesa-libGL-devel-18.3.4-5.amzn2.0.1.x86_64
# ---> Package pixman-devel.x86_64 0:0.34.0-1.amzn2.0.2 will be installed
# --> Running transaction check
# ---> Package expat-devel.x86_64 0:2.1.0-15.amzn2.0.3 will be installed
# ---> Package gl-manpages.noarch 0:1.1-7.20130122.amzn2 will be installed
# ---> Package libXau-devel.x86_64 0:1.0.8-2.1.amzn2.0.2 will be installed
# ---> Package libXdamage-devel.x86_64 0:1.1.4-4.1.amzn2.0.2 will be installed
# ---> Package libXfixes-devel.x86_64 0:5.0.3-1.amzn2.0.2 will be installed
# ---> Package libXxf86vm-devel.x86_64 0:1.1.4-1.amzn2.0.2 will be installed
# ---> Package libdrm-devel.x86_64 0:2.4.97-2.amzn2 will be installed
# ---> Package libuuid-devel.x86_64 0:2.30.2-2.amzn2.0.11 will be installed
# ---> Package mesa-khr-devel.x86_64 0:18.3.4-5.amzn2.0.1 will be installed
# ---> Package xorg-x11-proto-devel.noarch 0:2018.4-1.amzn2.0.2 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package                 Arch      Version                  Repository     Size
# ================================================================================
# Installing:
#  cairo-devel             x86_64    1.15.12-4.amzn2          amzn2-core    267 k
# Installing for dependencies:
#  expat-devel             x86_64    2.1.0-15.amzn2.0.3       amzn2-core     59 k
#  fontconfig-devel        x86_64    2.13.0-4.3.amzn2         amzn2-core    138 k
#  freetype-devel          x86_64    2.8-14.amzn2.1.2         amzn2-core    447 k
#  gl-manpages             noarch    1.1-7.20130122.amzn2     amzn2-core    993 k
#  glib2-devel             x86_64    2.56.1-9.amzn2.0.8       amzn2-core    453 k
#  libX11-devel            x86_64    1.6.7-3.amzn2.0.5        amzn2-core    982 k
#  libXau-devel            x86_64    1.0.8-2.1.amzn2.0.2      amzn2-core     14 k
#  libXdamage-devel        x86_64    1.1.4-4.1.amzn2.0.2      amzn2-core    9.8 k
#  libXext-devel           x86_64    1.3.3-3.amzn2.0.2        amzn2-core     75 k
#  libXfixes-devel         x86_64    5.0.3-1.amzn2.0.2        amzn2-core     13 k
#  libXrender-devel        x86_64    0.9.10-1.amzn2.0.2       amzn2-core     17 k
#  libXxf86vm-devel        x86_64    1.1.4-1.amzn2.0.2        amzn2-core     19 k
#  libdrm-devel            x86_64    2.4.97-2.amzn2           amzn2-core    144 k
#  libpng-devel            x86_64    2:1.5.13-8.amzn2.0.5     amzn2-core    122 k
#  libuuid-devel           x86_64    2.30.2-2.amzn2.0.11      amzn2-core     87 k
#  libxcb-devel            x86_64    1.12-1.amzn2.0.2         amzn2-core    1.0 M
#  mesa-khr-devel          x86_64    18.3.4-5.amzn2.0.1       amzn2-core     19 k
#  mesa-libEGL-devel       x86_64    18.3.4-5.amzn2.0.1       amzn2-core     33 k
#  mesa-libGL-devel        x86_64    18.3.4-5.amzn2.0.1       amzn2-core    163 k
#  pixman-devel            x86_64    0.34.0-1.amzn2.0.2       amzn2-core     20 k
#  xorg-x11-proto-devel    noarch    2018.4-1.amzn2.0.2       amzn2-core    280 k
#
# Transaction Summary
# ================================================================================
# Install  1 Package (+21 Dependent packages)
#
# Total download size: 5.3 M
# Installed size: 17 M
# Downloading packages:
# (1/22): expat-devel-2.1.0-15.amzn2.0.3.x86_64.rpm          |  59 kB   00:00
# (2/22): fontconfig-devel-2.13.0-4.3.amzn2.x86_64.rpm       | 138 kB   00:00
# (3/22): cairo-devel-1.15.12-4.amzn2.x86_64.rpm             | 267 kB   00:00
# (4/22): freetype-devel-2.8-14.amzn2.1.2.x86_64.rpm         | 447 kB   00:00
# (5/22): gl-manpages-1.1-7.20130122.amzn2.noarch.rpm        | 993 kB   00:00
# (6/22): glib2-devel-2.56.1-9.amzn2.0.8.x86_64.rpm          | 453 kB   00:00
# (7/22): libXau-devel-1.0.8-2.1.amzn2.0.2.x86_64.rpm        |  14 kB   00:00
# (8/22): libX11-devel-1.6.7-3.amzn2.0.5.x86_64.rpm          | 982 kB   00:00
# (9/22): libXdamage-devel-1.1.4-4.1.amzn2.0.2.x86_64.rpm    | 9.8 kB   00:00
# (10/22): libXext-devel-1.3.3-3.amzn2.0.2.x86_64.rpm        |  75 kB   00:00
# (11/22): libXfixes-devel-5.0.3-1.amzn2.0.2.x86_64.rpm      |  13 kB   00:00
# (12/22): libXxf86vm-devel-1.1.4-1.amzn2.0.2.x86_64.rpm     |  19 kB   00:00
# (13/22): libXrender-devel-0.9.10-1.amzn2.0.2.x86_64.rpm    |  17 kB   00:00
# (14/22): libpng-devel-1.5.13-8.amzn2.0.5.x86_64.rpm        | 122 kB   00:00
# (15/22): libdrm-devel-2.4.97-2.amzn2.x86_64.rpm            | 144 kB   00:00
# (16/22): libuuid-devel-2.30.2-2.amzn2.0.11.x86_64.rpm      |  87 kB   00:00
# (17/22): libxcb-devel-1.12-1.amzn2.0.2.x86_64.rpm          | 1.0 MB   00:00
# (18/22): mesa-khr-devel-18.3.4-5.amzn2.0.1.x86_64.rpm      |  19 kB   00:00
# (19/22): mesa-libEGL-devel-18.3.4-5.amzn2.0.1.x86_64.rpm   |  33 kB   00:00
# (20/22): mesa-libGL-devel-18.3.4-5.amzn2.0.1.x86_64.rpm    | 163 kB   00:00
# (21/22): pixman-devel-0.34.0-1.amzn2.0.2.x86_64.rpm        |  20 kB   00:00
# (22/22): xorg-x11-proto-devel-2018.4-1.amzn2.0.2.noarch.rp | 280 kB   00:00
# --------------------------------------------------------------------------------
# Total                                               10 MB/s | 5.3 MB  00:00
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
# Warning: RPMDB altered outside of yum.
#   Installing : xorg-x11-proto-devel-2018.4-1.amzn2.0.2.noarch              1/22
#   Installing : 2:libpng-devel-1.5.13-8.amzn2.0.5.x86_64                    2/22
#   Installing : freetype-devel-2.8-14.amzn2.1.2.x86_64                      3/22
#   Installing : mesa-khr-devel-18.3.4-5.amzn2.0.1.x86_64                    4/22
#   Installing : libdrm-devel-2.4.97-2.amzn2.x86_64                          5/22
#   Installing : libXau-devel-1.0.8-2.1.amzn2.0.2.x86_64                     6/22
#   Installing : libxcb-devel-1.12-1.amzn2.0.2.x86_64                        7/22
#   Installing : libX11-devel-1.6.7-3.amzn2.0.5.x86_64                       8/22
#   Installing : libXext-devel-1.3.3-3.amzn2.0.2.x86_64                      9/22
#   Installing : libXfixes-devel-5.0.3-1.amzn2.0.2.x86_64                   10/22
#   Installing : libXdamage-devel-1.1.4-4.1.amzn2.0.2.x86_64                11/22
#   Installing : libXxf86vm-devel-1.1.4-1.amzn2.0.2.x86_64                  12/22
#   Installing : mesa-libEGL-devel-18.3.4-5.amzn2.0.1.x86_64                13/22
#   Installing : libXrender-devel-0.9.10-1.amzn2.0.2.x86_64                 14/22
#   Installing : glib2-devel-2.56.1-9.amzn2.0.8.x86_64                      15/22
#   Installing : pixman-devel-0.34.0-1.amzn2.0.2.x86_64                     16/22
#   Installing : gl-manpages-1.1-7.20130122.amzn2.noarch                    17/22
#   Installing : mesa-libGL-devel-18.3.4-5.amzn2.0.1.x86_64                 18/22
#   Installing : expat-devel-2.1.0-15.amzn2.0.3.x86_64                      19/22
#   Installing : libuuid-devel-2.30.2-2.amzn2.0.11.x86_64                   20/22
#   Installing : fontconfig-devel-2.13.0-4.3.amzn2.x86_64                   21/22
#   Installing : cairo-devel-1.15.12-4.amzn2.x86_64                         22/22
#   Verifying  : freetype-devel-2.8-14.amzn2.1.2.x86_64                      1/22
#   Verifying  : libuuid-devel-2.30.2-2.amzn2.0.11.x86_64                    2/22
#   Verifying  : libXrender-devel-0.9.10-1.amzn2.0.2.x86_64                  3/22
#   Verifying  : expat-devel-2.1.0-15.amzn2.0.3.x86_64                       4/22
#   Verifying  : mesa-libGL-devel-18.3.4-5.amzn2.0.1.x86_64                  5/22
#   Verifying  : gl-manpages-1.1-7.20130122.amzn2.noarch                     6/22
#   Verifying  : libXau-devel-1.0.8-2.1.amzn2.0.2.x86_64                     7/22
#   Verifying  : libxcb-devel-1.12-1.amzn2.0.2.x86_64                        8/22
#   Verifying  : cairo-devel-1.15.12-4.amzn2.x86_64                          9/22
#   Verifying  : pixman-devel-0.34.0-1.amzn2.0.2.x86_64                     10/22
#   Verifying  : libdrm-devel-2.4.97-2.amzn2.x86_64                         11/22
#   Verifying  : mesa-khr-devel-18.3.4-5.amzn2.0.1.x86_64                   12/22
#   Verifying  : libXdamage-devel-1.1.4-4.1.amzn2.0.2.x86_64                13/22
#   Verifying  : glib2-devel-2.56.1-9.amzn2.0.8.x86_64                      14/22
#   Verifying  : mesa-libEGL-devel-18.3.4-5.amzn2.0.1.x86_64                15/22
#   Verifying  : 2:libpng-devel-1.5.13-8.amzn2.0.5.x86_64                   16/22
#   Verifying  : libXext-devel-1.3.3-3.amzn2.0.2.x86_64                     17/22
#   Verifying  : libXfixes-devel-5.0.3-1.amzn2.0.2.x86_64                   18/22
#   Verifying  : fontconfig-devel-2.13.0-4.3.amzn2.x86_64                   19/22
#   Verifying  : libXxf86vm-devel-1.1.4-1.amzn2.0.2.x86_64                  20/22
#   Verifying  : xorg-x11-proto-devel-2018.4-1.amzn2.0.2.noarch             21/22
#   Verifying  : libX11-devel-1.6.7-3.amzn2.0.5.x86_64                      22/22
#
# Installed:
#   cairo-devel.x86_64 0:1.15.12-4.amzn2
#
# Dependency Installed:
#   expat-devel.x86_64 0:2.1.0-15.amzn2.0.3
#   fontconfig-devel.x86_64 0:2.13.0-4.3.amzn2
#   freetype-devel.x86_64 0:2.8-14.amzn2.1.2
#   gl-manpages.noarch 0:1.1-7.20130122.amzn2
#   glib2-devel.x86_64 0:2.56.1-9.amzn2.0.8
#   libX11-devel.x86_64 0:1.6.7-3.amzn2.0.5
#   libXau-devel.x86_64 0:1.0.8-2.1.amzn2.0.2
#   libXdamage-devel.x86_64 0:1.1.4-4.1.amzn2.0.2
#   libXext-devel.x86_64 0:1.3.3-3.amzn2.0.2
#   libXfixes-devel.x86_64 0:5.0.3-1.amzn2.0.2
#   libXrender-devel.x86_64 0:0.9.10-1.amzn2.0.2
#   libXxf86vm-devel.x86_64 0:1.1.4-1.amzn2.0.2
#   libdrm-devel.x86_64 0:2.4.97-2.amzn2
#   libpng-devel.x86_64 2:1.5.13-8.amzn2.0.5
#   libuuid-devel.x86_64 0:2.30.2-2.amzn2.0.11
#   libxcb-devel.x86_64 0:1.12-1.amzn2.0.2
#   mesa-khr-devel.x86_64 0:18.3.4-5.amzn2.0.1
#   mesa-libEGL-devel.x86_64 0:18.3.4-5.amzn2.0.1
#   mesa-libGL-devel.x86_64 0:18.3.4-5.amzn2.0.1
#   pixman-devel.x86_64 0:0.34.0-1.amzn2.0.2
#   xorg-x11-proto-devel.noarch 0:2018.4-1.amzn2.0.2
#
# Complete!
# Installing Python package pygobject...
# Requirement already satisfied: pygobject in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (3.48.2)
# Upgrading pip...
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (24.2)
# Installing package...
# Using pip 24.2 from /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pip (python 3.10)
# Obtaining file:///home/ec2-user/SageMaker/Sam2Keras
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-c_ahweh_/sam2keras.egg-info
#   writing /tmp/pip-pip-egg-info-c_ahweh_/sam2keras.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-c_ahweh_/sam2keras.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-c_ahweh_/sam2keras.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-c_ahweh_/sam2keras.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-c_ahweh_/sam2keras.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-c_ahweh_/sam2keras.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-c_ahweh_/sam2keras.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow>=2.12 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sam2keras==0.1.0) (2.16.1)
# Requirement already satisfied: opencv-python in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sam2keras==0.1.0) (4.10.0.82)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sam2keras==0.1.0) (1.26.4)
# Requirement already satisfied: pygobject in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sam2keras==0.1.0) (3.48.2)
# Requirement already satisfied: absl-py>=1.0.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (3.3.0)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (2.32.3)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (4.12.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorflow>=2.12->sam2keras==0.1.0) (0.37.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.12->sam2keras==0.1.0) (0.43.0)
# Requirement already satisfied: rich in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.12->sam2keras==0.1.0) (13.7.1)
# Requirement already satisfied: namex in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.12->sam2keras==0.1.0) (0.0.8)
# Requirement already satisfied: optree in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.12->sam2keras==0.1.0) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12->sam2keras==0.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12->sam2keras==0.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12->sam2keras==0.1.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12->sam2keras==0.1.0) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.12->sam2keras==0.1.0) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.12->sam2keras==0.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.12->sam2keras==0.1.0) (3.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from packaging->tensorflow>=2.12->sam2keras==0.1.0) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow>=2.12->sam2keras==0.1.0) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow>=2.12->sam2keras==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow>=2.12->sam2keras==0.1.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow>=2.12->sam2keras==0.1.0) (0.1.2)
# Installing collected packages: sam2keras
#   DEPRECATION: Legacy editable install of sam2keras==0.1.0 from file:///home/ec2-user/SageMaker/Sam2Keras (setup.py develop) is deprecated. pip 25.0 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457
#   Running setup.py develop for sam2keras
#     Running command python setup.py develop
#     running develop
#     /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/setuptools/command/develop.py:42: EasyInstallDeprecationWarning: easy_install command is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` and ``easy_install``.
#             Instead, use pypa/build, pypa/installer or other
#             standards-based tools.
#
#             See https://github.com/pypa/setuptools/issues/917 for details.
#             ********************************************************************************
#
#     !!
#       easy_install.initialize_options(self)
#     /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` directly.
#             Instead, use pypa/build, pypa/installer or other
#             standards-based tools.
#
#             See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#             ********************************************************************************
#
#     !!
#       self.initialize_options()
#     running egg_info
#     creating sam2keras.egg-info
#     writing sam2keras.egg-info/PKG-INFO
#     writing dependency_links to sam2keras.egg-info/dependency_links.txt
#     writing requirements to sam2keras.egg-info/requires.txt
#     writing top-level names to sam2keras.egg-info/top_level.txt
#     writing manifest file 'sam2keras.egg-info/SOURCES.txt'
#     reading manifest file 'sam2keras.egg-info/SOURCES.txt'
#     writing manifest file 'sam2keras.egg-info/SOURCES.txt'
#     running build_ext
#     Creating /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sam2keras.egg-link (link to .)
#     sam2keras 0.1.0 is already the active version in easy-install.pth
#
#     Installed /home/ec2-user/SageMaker/Sam2Keras
# Successfully installed sam2keras

# %%
# In your Jupyter Notebook cell:
# %run train.py
# Out:
# 2024-08-23 23:13:08.279421: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-23 23:13:10.297232: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/SageMaker/Sam2Keras/train.py:4
#       1 # Sam2Keras/train.py
#       3 import tensorflow as tf
# ----> 4 from sam2keras.modeling.sam2_base import SAM2_Base
#       5 from sam2keras.modeling.backbones.image_encoder import ImageEncoder, FpnNeck
#       6 from sam2keras.modeling.backbones.hieradet import Hiera
#
# ModuleNotFoundError: No module named 'sam2keras'

# %%
# !ls
# Out:
# automatic_mask_generator.py	    sam2_image_predictor.py
# Backbones			    sam2keras.egg-info
# build_sam.py			    SAM2TrainTF.ipynb
# __init__.py			    sam2_video_predictor.py
# Modeling			    samkeras.zip
# new-workspace.jupyterlab-workspace  setup.py
# position_encoder.py		    train.py
# Sam				    zip.ipynb
# sam2_base.py
